# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-4996ee3d8d09> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     104       timeout_ms=timeout_ms,
#     105       ephemeral=True,
# --> 106       readonly=readonly)
#     107
#     108
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     123   if ephemeral:
#     124     _message.blocking_request(
# --> 125         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     126
#     127   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master')

# %%
import os
#改变当前工作目录到谷歌云盘的路径
path="/content/gdrive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master"
os.chdir(path)
os.listdir(path)
# Out:
# ['README.md',
#  'LICENSE',
#  'train_eval.py',
#  'utils.py',
#  'run.py',
#  'bert_pretrain',
#  'ERNIE_pretrain',
#  'pytorch_pretrained',
#  'THUCNews',
#  '__pycache__',
#  'models']

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 云端硬盘上的 py 文件
# from datasets import load_dataset, load_json_data

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 38.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 48.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 69.2 MB/s
# ...

# %%
pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 21.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 9.9 MB 57.8 MB/s
# ...
#      |████████████████████████████████| 140 kB 52.1 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...

# %%
# !python /content/gdrive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/run.py --model bert
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Loading data...
# 180000it [00:19, 9235.71it/s]
# 10000it [00:01, 8108.19it/s]
# 10000it [00:01, 9521.99it/s]
# Time usage: 0:00:22
# Epoch [1/3]
# /content/gdrive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/pytorch_pretrained/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1174.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# Iter:      0,  Train Loss:   2.3,  Train Acc:  7.03%,  Val Loss:   2.3,  Val Acc:  9.96%,  Time: 0:00:20 *
# Iter:    100,  Train Loss:  0.37,  Train Acc: 88.28%,  Val Loss:  0.36,  Val Acc: 89.75%,  Time: 0:01:54 *
# ...
