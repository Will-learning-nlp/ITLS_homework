# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/韵文散文分类--预训练应用
# Out:
# /content/drive/MyDrive/韵文散文分类--预训练应用

# %%
# %cd /content/drive/MyDrive/韵文散文分类--预训练应用/下载模型.py
# Out:
# [Errno 20] Not a directory: '/content/drive/MyDrive/韵文散文分类--预训练应用/下载模型.py'
# /content/drive/MyDrive/韵文散文分类--预训练应用

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 127 kB 19.8 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.12
#     Uninstalling urllib3-1.26.12:
#       Successfully uninstalled urllib3-1.26.12
# ...

# %% [markdown]
# /content/drive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/bert_pretrain

# %% [markdown]
# /content/drive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/ERNIE_pretrain

# %%
# !python 下载模型.py
# Out:
# Downloading: 100% 29.0/29.0 [00:00<00:00, 24.3kB/s]
# Downloading: 100% 624/624 [00:00<00:00, 464kB/s]
# Downloading: 100% 110k/110k [00:00<00:00, 18.1MB/s]
# Downloading: 100% 269k/269k [00:00<00:00, 13.5MB/s]
# Downloading: 100% 412M/412M [00:07<00:00, 58.4MB/s]
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# !python 下载模型2.py
# Out:
# Downloading: 100% 62.0/62.0 [00:00<00:00, 44.8kB/s]
# Downloading: 100% 470/470 [00:00<00:00, 327kB/s]
# Downloading: 100% 91.6k/91.6k [00:00<00:00, 12.9MB/s]
# Downloading: 100% 112/112 [00:00<00:00, 79.1kB/s]
# Downloading: 100% 402M/402M [00:07<00:00, 52.6MB/s]
# Some weights of the model checkpoint at nghuyong/ernie-1.0-base-zh were not used when initializing ErnieModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing ErnieModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 33.0 MB/s
# ...
#      |████████████████████████████████| 9.9 MB 47.6 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 140 kB 57.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...

# %%
# !python /content/drive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/run.py --model bert
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/run.py", line 20, in <module>
#     config = x.Config(dataset)
#   File "/content/drive/MyDrive/韵文散文分类--预训练应用/Bert-Chinese-Text-Classification-Pytorch-master/models/bert.py", line 17, in __init__
#     dataset + '/data/class.txt').readlines()]                                # 类别名单
# FileNotFoundError: [Errno 2] No such file or directory: 'THUCNews/data/class.txt'
